# %%
import pandas as pd

# %%
df=pd.read_csv('Laptop_Data.csv')
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#        Weight          Category  Screen_size  \
# 0     1.24 KG            مک‌بوک         13.6
# 1     1.24 KG            مک‌بوک         13.6
# 2     1.24 KG            مک‌بوک         13.6
# 3     1.24 KG            مک‌بوک         13.6
# 4     1.75 KG  نوت بوک (لپ تاپ)         15.6
# ...       ...               ...          ...
# 6251  2.19 KG  نوت بوک (لپ تاپ)         15.6
# 6252  1.11 KG          آلترابوک         13.3
# 6253  2.29 KG  نوت بوک (لپ تاپ)         15.6
# 6254  1.94 KG  نوت بوک (لپ تاپ)         14.0
# 6255  2.04 KG  نوت بوک (لپ تاپ)         15.6
#
#                                             Screen_type Screen_resolution  \
# 0     13.6inch (diagonal) LED-backlit display with I...       1600 * 2560
# 1     13.6inch (diagonal) LED-backlit display with I...       1600 * 2560
# 2     13.6inch (diagonal) LED-backlit display with I...       1600 * 2560
# 3     13.6inch (diagonal) LED-backlit display with I...       1600 * 2560
# ...

# %% [markdown]
# ## Weight

# %%
df['Weight']=df['Weight'].str.replace('KG','').astype('float64')

# %% [markdown]
# ## Category

# %%
df['Category'].isnull().sum()
# Out:
# 448

# %%
df['Category'].value_counts()
# Out:
# نوت بوک (لپ تاپ)    5553
# مک‌بوک               154
# آلترابوک              98
# میت بوک                2
# کروم بوک               1
# Name: Category, dtype: int64

# %%
df[df['Category'].isnull()]
# Out:
#       Weight Category  Screen_size          Screen_type Screen_resolution  \
# 311     2.30      NaN         15.6  TFT LED-Backlit LCD        768 * 1366
# 467     2.20      NaN         15.6                  NaN       1080 * 1920
# 468     2.20      NaN         15.6                  NaN       1080 * 1920
# 470     2.20      NaN         15.6                  NaN       1080 * 1920
# 510     2.32      NaN         15.6  TFT LED-backlit LCD        768 * 1366
# ...      ...      ...          ...                  ...               ...
# 5371    2.40      NaN         15.6  TFT LED-Backlit LCD        768 * 1366
# 5373    3.90      NaN         17.3        HD Anti Glare       1080 * 1920
# 5452    2.40      NaN         15.6  TFT LED-backlit LCD        768 * 1366
# 5455    2.40      NaN         15.6  TFT LED-Backlit LCD        768 * 1366
# 5457    2.40      NaN         15.6  TFT LED-Backlit LCD        768 * 1366
#
#      CPU_Brand CPU_series      CPU_model   RAM  Storage_amount Storage_type  \
# ...

# %% [markdown]
# ## Screen Size

# %%
df['Screen_size'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Screen type

# %%
counts=df['Screen_type'].value_counts()

# %%
counts.head(60)
# Out:
# TFT LED-backlit LCD                                                             1305
# IPS                                                                              618
# IPS LED-backlit LCD                                                              384
# IPS LCD                                                                          310
# TFT LED-Backlit LCD                                                              271
# WLED Backlit                                                                     177
# TN                                                                               161
# FULL HD                                                                          138
# HD                                                                               135
# Full HD                                                                          113
# 178°wide-view technology                                                         103
# ...

# %%
screentypelist=counts.index.to_list()

# %%
screentypelist
# Out:
# ['TFT LED-backlit LCD',
#  'IPS',
#  'IPS LED-backlit LCD',
#  'IPS LCD',
#  'TFT LED-Backlit LCD',
#  'WLED Backlit',
#  'TN',
#  'FULL HD',
#  'HD',
#  'Full HD',
#  '178°wide-view technology',
#  'PixelSense™ Display',
#  'IPS-Level',
#  'TFT',
#  'فول اچ دی',
#  'LED-backlit LCD',
#  'LED-backlit',
#  'IPS-level panel',
#  'Full HD (1920×1080)',
#  'OLED',
#  'FHD',
#  'LED-backlit FHD',
#  'FHD TN',
#  'WV',
#  'FHD IPS',
#  'LED-backlit IPS LCD',
#  'WLED-backlit LCD',
#  'TFT LED Backlit LCD',
#  'WLED-backlit',
#  'HD BrightView LED-backlit',
#  'Full HD TN',
#  'TFT LED-backlit IPS LCD',
#  'LED-backlit HD',
#  'IPS-Type G-SYNC Panel',
#  'Wide view',
#  'wide-view technology',
#  'LED Backlit',
#  'LED-backlit Full HD178° wide-view technology',
#  'WUXGA',
#  'IPS level panel',
#  'Full HD (1920×1080) IPS',
#  '15.6" (16:9) LED-backlit FHD (1920x1080) 60Hz Anti-Glare Panel with 45% NTSC',
#  '13.6inch (diagonal) LED-backlit display with IPS technology',
#  'Wide View',
# ...

# %%
import re

# %%
screentypelist = counts.index.to_list()
import re

def group_screen_type(screen_type):
    if re.search(r'IPS|LED-backlit|WLED|BrightView|Liquid Retina|OLED|Truelife|LCD|PixelSense|AMOLED|TruBrite|Retina|Gorilla Glass|InfinityEdge', screen_type):
        return 'IPS or LED-backlit'
    elif re.search(r'TFT|TN|HD|Full HD|FHD|WV|SVA|Anti-Glare|True Life|WLED|BrightView', screen_type):
        return 'TFT or HD'
    elif re.search(r'4K|UHD|QHD|WUXGA|Ultra|TruBrite|XDR', screen_type):
        return 'High Resolution'
    else:
        return 'Others'

# Group the screen types
grouped_screen_types = [group_screen_type(screen_type) for screen_type in screentypelist]

# Find unique grouped screen types
unique_grouped_screen_types = list(set(grouped_screen_types))

print(unique_grouped_screen_types)
# Out:
# ['Others', 'TFT or HD', 'High Resolution', 'IPS or LED-backlit']

# %%
screentypelist = counts.index.to_list()
import re

def group_screen_type(screen_type):
    if re.search(r'IPS|LED-backlit|WLED|BrightView|Liquid Retina|OLED|Truelife|LCD|PixelSense|AMOLED|TruBrite|Retina|Gorilla Glass|InfinityEdge', screen_type):
        return 'IPS or LED-backlit'
    elif re.search(r'TFT|TN', screen_type):
        return 'TFT or TN'
    elif re.search(r'HD|Full HD|FHD', screen_type):
        return 'HD or Full HD'
    elif re.search(r'WV|SVA', screen_type):
        return 'WV or SVA'
    elif re.search(r'Anti-Glare|True Life', screen_type):
        return 'Anti-Glare or True Life'
    elif re.search(r'WLED|BrightView', screen_type):
        return 'WLED or BrightView'
    elif re.search(r'4K|UHD', screen_type):
        return '4K or UHD'
    elif re.search(r'QHD|WUXGA', screen_type):
        return 'QHD or WUXGA'
    elif re.search(r'Ultra|TruBrite', screen_type):
        return 'Ultra or TruBrite'
    elif re.search(r'XDR', screen_type):
        return 'XDR'
    else:
        return 'Others'

# Group the screen types
grouped_screen_types = [group_screen_type(screen_type) for screen_type in screentypelist]

# Find unique grouped screen types
unique_grouped_screen_types = list(set(grouped_screen_types))

print(unique_grouped_screen_types)
# Out:
# ['IPS or LED-backlit', '4K or UHD', 'QHD or WUXGA', 'TFT or TN', 'Anti-Glare or True Life', 'HD or Full HD', 'WV or SVA', 'Others']

# %%
# Create a dictionary mapping the original screen types to the grouped ones
screen_type_dict = {screen_type: group_screen_type(screen_type) for screen_type in screentypelist}

# Replace the original screen types with the grouped ones in the DataFrame
df['Screen_type'] = df['Screen_type'].replace(screen_type_dict)

# %%
df['Screen_type'].value_counts()
# Out:
# IPS or LED-backlit         4280
# HD or Full HD               616
# Others                      356
# TFT or TN                   328
# WV or SVA                    32
# Anti-Glare or True Life      21
# QHD or WUXGA                 18
# 4K or UHD                     4
# Name: Screen_type, dtype: int64

# %%
df
# Out:
#       Weight          Category  Screen_size         Screen_type  \
# 0       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 1       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 2       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 3       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 4       1.75  نوت بوک (لپ تاپ)         15.6           TFT or TN
# ...      ...               ...          ...                 ...
# 6251    2.19  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6252    1.11          آلترابوک         13.3  IPS or LED-backlit
# 6253    2.29  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6254    1.94  نوت بوک (لپ تاپ)         14.0  IPS or LED-backlit
# 6255    2.04  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
#
#      Screen_resolution CPU_Brand CPU_series  \
# 0          1600 * 2560     Apple         M2
# 1          1600 * 2560     Apple         M2
# 2          1600 * 2560     Apple         M2
# ...

# %% [markdown]
# ## Screen Resolution

# %%
df['Screen_resolution'].value_counts()
# Out:
# 1080 * 1920    3874
# 768 * 1366     1760
# 1600 * 2560     160
# 2160 * 3840     120
# 1440 * 2560      71
# 1800 * 2880      47
# 2256 * 1504      37
# 1200*1920        28
# 2000 * 3000      21
# 900 * 1600       18
# 3456*2234        15
# 1800 * 3200      15
# 1440 * 2304      13
# 900 * 1440       10
# 3024*1964         9
# 2160 * 4095       7
# 1620 * 2880       5
# 800 * 1280        2
# 2560*1920         1
# Name: Screen_resolution, dtype: int64

# %% [markdown]
# ## CPU Brand

# %%
df['CPU_Brand'].value_counts()
# Out:
# INTEL    5421
# AMD       762
# Apple      72
# Name: CPU_Brand, dtype: int64

# %%
df['CPU_Brand'].isnull().sum()
# Out:
# 1

# %%
df['CPU_Brand'].fillna('INTEL',inplace=True)

# %%
df[df['CPU_Brand'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Weight, Category, Screen_size, Screen_type, Screen_resolution, CPU_Brand, CPU_series, CPU_model, RAM, Storage_amount, Storage_type, Storage_info, GPU_Brand, GPU_Model, OS, original_price, after_discount, persian_info, full_info, discount_percent]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6256 entries, 0 to 6255
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             6256 non-null   float64
#  1   Category           5808 non-null   object
#  2   Screen_size        6256 non-null   float64
#  3   Screen_type        5655 non-null   object
#  4   Screen_resolution  6213 non-null   object
#  5   CPU_Brand          6256 non-null   object
#  6   CPU_series         6059 non-null   object
#  7   CPU_model          5911 non-null   object
#  8   RAM                6256 non-null   float64
#  9   Storage_amount     6254 non-null   float64
#  10  Storage_type       6251 non-null   object
#  11  Storage_info       1840 non-null   object
#  12  GPU_Brand          6245 non-null   object
#  13  GPU_Model          6105 non-null   object
#  14  OS                 3395 non-null   object
#  15  original_price     325 non-null    float64
# ...

# %% [markdown]
# ## Cpu Series

# %%
df['CPU_series'].value_counts()
# Out:
# Core i7          2566
# Core i5          1606
# Core i3           835
# Ryzen 7           200
# Ryzen 5           171
# Celeron           167
# Pentium           117
# Core i9            89
# Ryzen 3            80
# Ryzen 9            52
# M2                 29
# Bristol Ridge      27
# Athlon             21
# M1                 19
# Xeon               18
# Stoney Ridge       14
# Carrizo            12
# Core-M              9
# M2 Pro              8
# M1 Pro              8
# M1 Max              6
# M2 MAX              2
# Atom                2
# Core-M3             1
# Name: CPU_series, dtype: int64

# %% [markdown]
# ## CPU series

# %%
df['CPU_series'].value_counts()
# Out:
# Core i7          2566
# Core i5          1606
# Core i3           835
# Ryzen 7           200
# Ryzen 5           171
# Celeron           167
# Pentium           117
# Core i9            89
# Ryzen 3            80
# Ryzen 9            52
# M2                 29
# Bristol Ridge      27
# Athlon             21
# M1                 19
# Xeon               18
# Stoney Ridge       14
# Carrizo            12
# Core-M              9
# M2 Pro              8
# M1 Pro              8
# M1 Max              6
# M2 MAX              2
# Atom                2
# Core-M3             1
# Name: CPU_series, dtype: int64

# %% [markdown]
# ## CPU model

# %%
df['CPU_model'].value_counts()
# Out:
# i5-1135G7       257
# i7 1165G7       217
# I3-1115G4       215
# i7 10750H       207
# i7-8550U        185
#                ...
# i5-3437U          1
# Pentium-3710      1
# i5-3317U          1
# i5-4310U          1
# A6-5200           1
# Name: CPU_model, Length: 299, dtype: int64

# %% [markdown]
# ## RAM

# %%
df['RAM'].value_counts()
# Out:
# 8.0      2187
# 16.0     1621
# 4.0      1007
# 12.0      498
# 32.0      486
# 6.0       156
# 24.0       87
# 20.0       81
# 2.0        65
# 64.0       49
# 40.0       14
# 36.0        3
# 128.0       2
# Name: RAM, dtype: int64

# %%
df
# Out:
#       Weight          Category  Screen_size         Screen_type  \
# 0       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 1       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 2       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 3       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 4       1.75  نوت بوک (لپ تاپ)         15.6           TFT or TN
# ...      ...               ...          ...                 ...
# 6251    2.19  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6252    1.11          آلترابوک         13.3  IPS or LED-backlit
# 6253    2.29  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6254    1.94  نوت بوک (لپ تاپ)         14.0  IPS or LED-backlit
# 6255    2.04  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
#
#      Screen_resolution CPU_Brand CPU_series  \
# 0          1600 * 2560     Apple         M2
# 1          1600 * 2560     Apple         M2
# 2          1600 * 2560     Apple         M2
# ...

# %% [markdown]
# ## Storage amount

# %%
df['Storage_amount'].value_counts().index.sort_values(ascending=False)
# Out:
# Float64Index([2562622464.0,  132055040.0,  131840000.0,   33280000.0,
#                 16896000.0,    9831424.0,    8960000.0,    8704000.0,
#                  5244928.0,    5244416.0,    5243904.0,    5121024.0,
#                  4917248.0,    4916224.0,    2623488.0,    2622464.0,
#                  2562048.0,    2561024.0,    2459648.0,    2458624.0,
#                  1312768.0,    1311744.0,    1230848.0,    1229824.0,
#                   983040.0,     768000.0,     655360.0,     524288.0,
#                   512000.0,     327680.0,     262144.0,     256000.0,
#                   247808.0,     247296.0,     246784.0,     196608.0,
#                   165888.0,     164864.0,     131072.0,      83968.0,
#                    82944.0,      65536.0,      32768.0,      16384.0,
#                     4096.0,       2048.0,       1536.0,       1024.0],
#              dtype='float64')

# %%
df['Storage_amount'].value_counts()
# Out:
# 1.024000e+03    2475
# 5.242880e+05     885
# 2.622464e+06     656
# 5.120000e+05     504
# 1.311744e+06     398
# 2.621440e+05     387
# 5.243904e+06     307
# 2.048000e+03     175
# 1.310720e+05      70
# 2.561024e+06      66
# 5.121024e+06      59
# 1.229824e+06      48
# 8.294400e+04      41
# 7.680000e+05      40
# 2.623488e+06      28
# 1.312768e+06      23
# 8.704000e+06       9
# 2.458624e+06       8
# 3.276800e+04       7
# 1.648640e+05       7
# 2.467840e+05       6
# 5.244928e+06       6
# 1.536000e+03       5
# 3.276800e+05       3
# 4.096000e+03       3
# 4.917248e+06       3
# 9.831424e+06       3
# 2.562622e+09       3
# 4.916224e+06       3
# 2.459648e+06       3
# 6.553600e+04       3
# 2.472960e+05       2
# 2.560000e+05       2
# 1.320550e+08       2
# 1.966080e+05       1
# 2.478080e+05       1
# 8.396800e+04       1
# 1.658880e+05       1
# 1.318400e+08       1
# 1.230848e+06       1
# 8.960000e+06       1
# 6.553600e+05       1
# 3.328000e+07       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6256 entries, 0 to 6255
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             6256 non-null   float64
#  1   Category           5808 non-null   object
#  2   Screen_size        6256 non-null   float64
#  3   Screen_type        5655 non-null   object
#  4   Screen_resolution  6213 non-null   object
#  5   CPU_Brand          6256 non-null   object
#  6   CPU_series         6059 non-null   object
#  7   CPU_model          5911 non-null   object
#  8   RAM                6256 non-null   float64
#  9   Storage_amount     6254 non-null   float64
#  10  Storage_type       6251 non-null   object
#  11  Storage_info       1840 non-null   object
#  12  GPU_Brand          6245 non-null   object
#  13  GPU_Model          6105 non-null   object
#  14  OS                 3395 non-null   object
#  15  original_price     325 non-null    float64
# ...

# %% [markdown]
# ## Storage type

# %%
def clean_column(df, column):
    df[column] = df[column].replace({
        'SSDHDD': 'SSD, HDD',
        'SSDSATA': 'SSD, SATA',
        'SSDحافظه‌های هیبردی': 'SSD, Hybrid Storage',
        'SSDHDDحافظه‌های هیبردی': 'SSD, HDD, Hybrid Storage',
        'SSDSSHD': 'SSD, SSHD',
        'SSHDSATA': 'SSHD, SATA',
        'SSDSATAحافظه‌های هیبردی': 'SSD, SATA, Hybrid Storage',
        'حافظه‌های هیبردی':'Hybrid'
    })
    return df

df = clean_column(df, 'Storage_type')
df['Storage_type']=df['Storage_type'].replace(['SSD, Hybrid Storage','SSD, HDD, Hybrid Storage',
                                              'SSHD','SSD, SSHD'],'Hybrid')
df['Storage_type']=df['Storage_type'].replace('','eMMC')
df['Storage_type']=df['Storage_type'].replace(['SSD, HDD','Hybrid'],'Hybrid')
df['Storage_type']=df['Storage_type'].replace(['SSD, SATA, Hybrid Storage','SSHD, SATA'],'SSD, SATA')

# %%
df['Storage_type'].value_counts()
# Out:
# SSD          2283
# Hybrid       1440
# SATA         1370
# HDD           874
# SSD, SATA     277
# eMMC            7
# Name: Storage_type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6256 entries, 0 to 6255
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             6256 non-null   float64
#  1   Category           5808 non-null   object
#  2   Screen_size        6256 non-null   float64
#  3   Screen_type        5655 non-null   object
#  4   Screen_resolution  6213 non-null   object
#  5   CPU_Brand          6256 non-null   object
#  6   CPU_series         6059 non-null   object
#  7   CPU_model          5911 non-null   object
#  8   RAM                6256 non-null   float64
#  9   Storage_amount     6254 non-null   float64
#  10  Storage_type       6251 non-null   object
#  11  Storage_info       1840 non-null   object
#  12  GPU_Brand          6245 non-null   object
#  13  GPU_Model          6105 non-null   object
#  14  OS                 3395 non-null   object
#  15  original_price     325 non-null    float64
# ...

# %% [markdown]
# ## GPU Brand

# %%
df['GPU_Brand'].value_counts()
# Out:
# Nvidia Gforce    3429
# Intel            1336
# AMD Radeon        781
# Nvidia            382
# AMD               245
# Apple              72
# Name: GPU_Brand, dtype: int64

# %% [markdown]
# ## GPU Model

# %%
df['GPU_Model']
# Out:
# 0            10 هسته ای
# 1            10 هسته ای
# 2                   NaN
# 3            10 هسته ای
# 4                   UHD
#              ...
# 6251            R5 M330
# 6252    HD Graphics 620
# 6253            GT 940M
# 6254            R5 M430
# 6255            R5 M430
# Name: GPU_Model, Length: 6256, dtype: object

# %%
df['GPU_Model'].value_counts()
# Out:
# Intel® UHD Graphics     120
# MX130                   108
# NVIDIA Geforce MX330    101
# GTX 1650                 96
# MX110                    92
#                        ...
# R9 M370X GDDR5            1
# R3 Graphics intel         1
# Radeon™ R7 M360           1
# Intel HD 520              1
# Fire Pro                  1
# Name: GPU_Model, Length: 866, dtype: int64

# %%
df['GPU_Model'] = df['GPU_Model'].str.lower().str.strip()
df['GPU_Model'] = df['GPU_Model'].str.replace('دارای', 'has')
df['GPU_Model'] = df['GPU_Model'].str.replace('هسته', 'core')
df['GPU_Model'] = df['GPU_Model'].str.replace('پردازش گرافیکی', '')
df['GPU_Model'] = df['GPU_Model'].str.replace('ای', '')
df['GPU_Model'] = df['GPU_Model'].str.replace('۵۵۰', '550')
df['GPU_Model'] = df['GPU_Model'].replace(['uhd','uhd graphics', 'intel® hd graphics','intel uhd graphic','intel® uhd graphics','intel uhd graphics','intel'], 'uhd')
df['GPU_Model'] = df['GPU_Model'].replace(['nvidia geforce mx330', 'geforce® mx330'], 'geforce mx330')
df['GPU_Model'] = df['GPU_Model'].replace(['nvidia® geforce rtx™3050 ti  laptop gpu with 4gb gddr6','geforce rtx3050', 'rtx 3050','rtx 3050 gddr6','nvidia geforce rtx 3050','rtx™ a2000'], 'rtx 3050')
df['GPU_Model'] = df['GPU_Model'].replace(['intel® iris® xe', 'intel iris xe graphics'], 'iris xe graphics')
df['GPU_Model'] = df['GPU_Model'].replace(['mx350', 'nvidia geforce mx350'], 'geforce mx350')
df['GPU_Model'] = df['GPU_Model'].replace(['geforce mx550 gddr6 - 2gb', 'mx550 gddr6','geforce mx550','nvida mx 550'], 'mx550 gddr6')
df['GPU_Model'] = df['GPU_Model'].replace(['iris xe graphics', 'intel iris plus graphics','intel iris','intel® iris™ plus graphics'], 'iris plus')
df['GPU_Model'] = df['GPU_Model'].replace(['radeon rx6600m gdd6', 'amd radeon'], 'radeon rx6600m')
df['GPU_Model'] = df['GPU_Model'].replace(['nvidia geforce mx450', 'mx450'], 'geforce mx450')
df['GPU_Model'] = df['GPU_Model'].replace(['geforce rtx 3060 gddr6', 'geforce rtx 3060'], 'geforce rtx 3060')
df['GPU_Model'] = df['GPU_Model'].replace(['gtx 1650 with max-q design', 'nvidia geforce gtx 1650'], 'geforce rtx 3060')
df['GPU_Model'] = df['GPU_Model'].replace(['geforce rtx 4060', 'geforce rtx4060 gddr6'], 'geforce rtx 4060')
df['GPU_Model'] = df['GPU_Model'].replace(['has 19 core','has 16 core'],'M2 Pro')
df['GPU_Model'] = df['GPU_Model'].replace(['10-core gpu','10 core','10core gpu16-core neural engine100gb/s memory bandwidth','10 core'],'M2 10')
df['GPU_Model'] = df['GPU_Model'].replace(['14core gpu16core neural engine200gb/s memory bandwidth','has 16 core','16core gpu16core neural engine200gb/s memory bandwidth'],'M 16')
df['GPU_Model'] = df['GPU_Model'].replace('has 38 core','M2 Max')

# %%
for i in df['GPU_Model']:
    print(i)
# Out:
# 10 core
# 10 core
# nan
# 10 core
# uhd
# M 16
# M 16
# M 16
# nan
# M 16
# 10 core
# M 16
# M 16
# M2 10
# M2 10
# M2 10
# M 16
# 7core apple-designed integrated gpu
# M2 10
# nan
# geforce® gtx 1050 gddr5
# mx550 gddr6
# mx350 gddr5
# geforce rtx 3060
# mx550 gddr6
# geforce rtx 3060
# iris plus
# gtx 1060 gddr5
# uhd
# iris plus
# powered by amd ryzen™ microsoft surface® edition: amd radeon™ graphics
# uhd
# uhd
# uhd
# mx550 gddr6
# amd ryzen™ microsoft surface® edition: amd radeon™ graphics
# iris plus
# iris plus
# powered by amd ryzen™ microsoft surface® edition: amd radeon™ graphics
# intel® iris® xe graphics
# iris plus
# iris plus
# gtx 1660 ti
# iris plus
# iris plus
# iris plus
# geforce mx330
# uhd
# uhd
# uhd
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# rtx 3050
# geforce mx350
# geforce mx350
# uhd
# geforce mx350
# uhd
# uhd
# uhd
# geforce mx350
# uhd
# geforce mx450
# geforce mx450
# uhd
# geforce mx450
# ...

# %%
df=df[df['GPU_Model'].notnull()]
df['GPU_Model'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 6105 entries, 0 to 6255
# Series name: GPU_Model
# Non-Null Count  Dtype
# --------------  -----
# 6105 non-null   object
# dtypes: object(1)
# memory usage: 95.4+ KB

# %%
df
# Out:
#       Weight          Category  Screen_size         Screen_type  \
# 0       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 1       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 3       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 4       1.75  نوت بوک (لپ تاپ)         15.6           TFT or TN
# 5       1.60            مک‌بوک         14.2  IPS or LED-backlit
# ...      ...               ...          ...                 ...
# 6251    2.19  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6252    1.11          آلترابوک         13.3  IPS or LED-backlit
# 6253    2.29  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6254    1.94  نوت بوک (لپ تاپ)         14.0  IPS or LED-backlit
# 6255    2.04  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
#
#      Screen_resolution CPU_Brand CPU_series  \
# 0          1600 * 2560     Apple         M2
# 1          1600 * 2560     Apple         M2
# 3          1600 * 2560     Apple         M2
# ...

# %% [markdown]
# ## OS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6105 entries, 0 to 6255
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             6105 non-null   float64
#  1   Category           5658 non-null   object
#  2   Screen_size        6105 non-null   float64
#  3   Screen_type        5530 non-null   object
#  4   Screen_resolution  6064 non-null   object
#  5   CPU_Brand          6105 non-null   object
#  6   CPU_series         5913 non-null   object
#  7   CPU_model          5775 non-null   object
#  8   RAM                6105 non-null   float64
#  9   Storage_amount     6103 non-null   float64
#  10  Storage_type       6100 non-null   object
#  11  Storage_info       1812 non-null   object
#  12  GPU_Brand          6099 non-null   object
#  13  GPU_Model          6105 non-null   object
#  14  OS                 3317 non-null   object
#  15  original_price     318 non-null    float64
# ...

# %%
df['OS'].value_counts()
# Out:
# Dos                         2608
# Microsoft Windows 10         350
# Apple Mac OS                 127
# Microsoft Windows 11          88
# Microsoft Windows 8           53
# Microsoft Windows 8.1         48
# Microsoft Windows 7           19
# Microsoft Windows 10 Pro      14
# Microsoft Windows 7 Pro        5
# Microsoft Windows 8 Pro        3
# Win 8.1 Original               2
# Name: OS, dtype: int64

# %%
# df=df[df['OS'].notnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6105 entries, 0 to 6255
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             6105 non-null   float64
#  1   Category           5658 non-null   object
#  2   Screen_size        6105 non-null   float64
#  3   Screen_type        5530 non-null   object
#  4   Screen_resolution  6064 non-null   object
#  5   CPU_Brand          6105 non-null   object
#  6   CPU_series         5913 non-null   object
#  7   CPU_model          5775 non-null   object
#  8   RAM                6105 non-null   float64
#  9   Storage_amount     6103 non-null   float64
#  10  Storage_type       6100 non-null   object
#  11  Storage_info       1812 non-null   object
#  12  GPU_Brand          6099 non-null   object
#  13  GPU_Model          6105 non-null   object
#  14  OS                 3317 non-null   object
#  15  original_price     318 non-null    float64
# ...

# %%
df['OS'].isnull().sum()
# Out:
# 2788

# %%
import pandas as pd

def replace_nan(df):
    df.loc[(df['OS'].isnull()) & (df['CPU_Brand'] == 'Apple'), 'OS'] = 'Apple Mac OS'
    df.loc[(df['OS'].isnull()) & (df['CPU_Brand'] == 'INTEL'), 'OS'] = 'Windows X'
    df.loc[(df['OS'].isnull()) & (df['CPU_Brand'] == 'AMD'), 'OS'] = 'Windows Y'
    return df

df = replace_nan(df)

# %%
df['OS'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#       Weight          Category  Screen_size         Screen_type  \
# 0       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 1       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 3       1.24            مک‌بوک         13.6  IPS or LED-backlit
# 4       1.75  نوت بوک (لپ تاپ)         15.6           TFT or TN
# 5       1.60            مک‌بوک         14.2  IPS or LED-backlit
# ...      ...               ...          ...                 ...
# 6251    2.19  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6252    1.11          آلترابوک         13.3  IPS or LED-backlit
# 6253    2.29  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
# 6254    1.94  نوت بوک (لپ تاپ)         14.0  IPS or LED-backlit
# 6255    2.04  نوت بوک (لپ تاپ)         15.6  IPS or LED-backlit
#
#      Screen_resolution CPU_Brand CPU_series  \
# 0          1600 * 2560     Apple         M2
# 1          1600 * 2560     Apple         M2
# 3          1600 * 2560     Apple         M2
# ...

# %%
df.isnull().sum()
# Out:
# Weight                  0
# Category              447
# Screen_size             0
# Screen_type           575
# Screen_resolution      41
# CPU_Brand               0
# CPU_series            192
# CPU_model             330
# RAM                     0
# Storage_amount          2
# Storage_type            5
# Storage_info         4293
# GPU_Brand               6
# GPU_Model               0
# OS                      0
# original_price       5787
# after_discount       5699
# persian_info            0
# full_info               0
# discount_percent        0
# dtype: int64

# %%
df['Category'].value_counts()
# Out:
# نوت بوک (لپ تاپ)    5412
# مک‌بوک               145
# آلترابوک              98
# میت بوک                2
# کروم بوک               1
# Name: Category, dtype: int64

# %%
df['Category']=df['Category'].str.replace('مک‌بوک','مک بوک')
# Out:
# C:\Users\IDEH\AppData\Local\Temp\ipykernel_528\3344314074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']=df['Category'].str.replace('مک‌بوک','مک بوک')

# %%
df['persian_info']
# Out:
# 0       لپ تاپ اپل 13.6 اینچی مدل Apple MacBook Air 20...
# 1       لپ تاپ اپل 13.6 اینچی مدل Apple MacBook Air 20...
# 3       لپ تاپ اپل 13.6 اینچی مدل Apple MacBook Air 20...
# 4       لپ تاپ لنوو 15.6 اینچی مدل Ideapad 3 پردازنده ...
# 5       لپ تاپ اپل 14 اینچ مدل Mac Book Pro 14inch MKG...
#                               ...
# 6251                لپ تاپ اچ پی ای سی 170 با پردازنده i7
# 6252    لپ تاپ اچ پی مدل Spectre 13T-V100 با پردازنده ...
# 6253      لپ تاپ اچ پی مدل ای بی 248 ان ای با پردازنده i5
# 6254    لپ تاپ اچ پی مدل ای ام 099 با پردازنده i3 و صف...
# 6255           لپ تاپ اچ پی مدل ای وای 080 با پردازنده i5
# Name: persian_info, Length: 6105, dtype: object

# %%
import pandas as pd

def replace_nan_category(df):
    df.loc[(df['Category'].isnull()) & (df['CPU_Brand'] == 'Apple'), 'Category'] = 'مک بوک'
    df.loc[(df['Category'].isnull()) & (df['CPU_Brand'] == 'INTEL'), 'Category'] = 'نوت بوک (لپ تاپ)'
    df.loc[(df['Category'].isnull()) , 'Category'] ='نوت بوک (لپ تاپ)'

    return df

df = replace_nan_category(df)

# %%
df.isnull().sum()
# Out:
# Weight                  0
# Category                0
# Screen_size             0
# Screen_type           575
# Screen_resolution      41
# CPU_Brand               0
# CPU_series            192
# CPU_model             330
# RAM                     0
# Storage_amount          2
# Storage_type            5
# Storage_info         4293
# GPU_Brand               6
# GPU_Model               0
# OS                      0
# original_price       5787
# after_discount       5699
# persian_info            0
# full_info               0
# discount_percent        0
# dtype: int64

# %%
df.to_csv('Cleaned2.csv',encoding='utf-8')
